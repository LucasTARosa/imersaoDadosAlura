# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasTARosa/imersaoDadosAlura/blob/main/Aula_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 2

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
mapa = {'droga':'composto'}
dados.rename(columns=mapa, inplace = True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.columns = dados.columns.str.replace('-','')

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
import seaborn as sns

sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'))

# %%
cod_compostos = dados['composto'].value_counts()[0:5].index
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
composto1 = dados['composto'].value_counts()[0:1].index
composto1
# Out:
# Index(['cacb2b860'], dtype='object')

# %%
dados.query('composto in @composto1')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47     id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63     id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ...  0.2131 -0.1419 -0.2422  0.0457
# 23747  id_ff469c482  com_controle     72   D1  ... -0.9630  0.8872 -0.0742 -0.6777
# 23768  id_ff89331ca  com_controle     72   D2  ...  0.9517 -0.8110 -0.1748 -0.3626
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# ...

# %%
sns.boxplot(x='g0', data=dados.query('composto in @composto1'))

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import matplotlib.pyplot as plt
sns.set()
sns.countplot(x='composto', data=dados.query('composto in @cod_compostos'))
plt.figure(figsize=(10,8))

# %%
ax = sns.countplot(x='composto', data=dados.query('composto in @cod_compostos'))
plt.figure(figsize=(8, 6))
ax.set_title('Compostos mais frequentes', fontsize = 18)
ax.set_xlabel('Compostos', fontsize = 14)
ax.set_ylabel('Contagem', fontsize = 14)

plt.show()

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].max()
# Out:
# 10.0

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].hist(bins = 100)

# %%
dados['g0'].describe()
# Out:
# count    23814.000000
# mean         0.248366
# std          1.393399
# min         -5.513000
# 25%         -0.473075
# 50%         -0.008850
# 75%          0.525700
# max         10.000000
# Name: g0, dtype: float64

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g0','g1']].describe()
# Out:
#                  g0            g1
# count  23814.000000  23814.000000
# mean       0.248366     -0.095684
# std        1.393399      0.812363
# min       -5.513000     -5.737000
# 25%       -0.473075     -0.562200
# 50%       -0.008850     -0.046600
# 75%        0.525700      0.403075
# max       10.000000      5.039000

# %%
dados.loc[:,'g0':'g771'].describe().T['mean'].hist(bins=50)

# %%
dados.loc[:,'g0':'g771'].describe().T['min'].hist(bins=50)

# %%
dados.loc[:,'g0':'g771'].describe().T['max'].hist(bins=50)

# %%
dados.loc[:,'c0':'c99'].describe()
# Out:
#                  c0            c1  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      -0.355156     -0.455359  ...     -0.470252     -0.301505
# std        1.752565      2.004962  ...      1.834828      1.407918
# min      -10.000000    -10.000000  ...    -10.000000    -10.000000
# 25%       -0.549300     -0.538425  ...     -0.592600     -0.562900
# 50%       -0.009000      0.009800  ...      0.014000     -0.019500
# 75%        0.448975      0.476875  ...      0.461275      0.438650
# max        3.365000      3.915000  ...      3.111000      3.805000
#
# [8 rows x 100 columns]

# %%
dados.loc[:,'c0':'c99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='g0', data=dados)

# %%
sns.boxplot(x='g0', y='tratamento', data=dados)

# %%
sns.boxplot(y='g0', x='tratamento', data=dados)
plt.figure(figsize=(10,8))

# %% [markdown]
# ## Aula 2
# ### Desafio 1: ordenar o gráfico countplot :check
# ### Desafio 2: melhorar a parte estética alterando o tamanho da fonte e os labels :check
# ### Desafio 3: plotar os histogramas com seaborn
# ### Desafio 4: estudar sobre as estatísticas retornadas no .describe() :check
# ### Desafio 5: Refletir sobre a manipulação do tamanho das visualizações. :check
# ### Desafio 6: Fazer outras análises com o boxplot e até com o histograma.
# ### Desafio 7: Resumo do que você aprendeu com os dados. :check

# %% [markdown]
# ## Desafio 1 e 2

# %%
ax = sns.countplot(x='composto', data=dados.query('composto in @cod_compostos'), order=['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'])
plt.figure(figsize=(10, 8))
ax.set_title('Compostos mais frequentes', fontsize = 18)
ax.set_xlabel('Compostos', fontsize = 14)
ax.set_ylabel('Contagem', fontsize = 14)
sns.set_palette(sns.color_palette('winter', 5))
plt.show()

# %% [markdown]
# ## Desafio 3

# %% [markdown]
# Deixo aqui um material muito interessante para consulta, de quem tiver interesse (inclusive o meu eu do futuro) https://seaborn.pydata.org/generated/seaborn.histplot.html

# %%
dados['g0'].describe()
# Out:
# count    23814.000000
# mean         0.248366
# std          1.393399
# min         -5.513000
# 25%         -0.473075
# 50%         -0.008850
# 75%          0.525700
# max         10.000000
# Name: g0, dtype: float64

# %%
sns.histplot(data=dados, x='g0')

# %%
sns.histplot(data=dados, x='g0', bins=30)

# %%
sns.histplot(data=dados, x='g0', kde=True)

# %%
sns.histplot(data=dados, x='g0', hue='tratamento')

# %%
sns.histplot(data=dados, x='g0', hue='tratamento', element='step')

# %%
sns.histplot(data=dados, x='g0', hue='tratamento', element='poly')

# %%
sns.histplot(data=dados, x='g0', stat='probability', discrete=True)

# %%
sns.histplot(data=dados, x='g0', fill=False, bins=30)

# %%
sns.histplot(data=dados, x='g0', y='tratamento', bins=50)

# %% [markdown]
# ##Desafio 4 e 5
#
# Fica a dica de um material muito bom sobre o assunto proposto nestes desafios https://medium.com/@gisely.alves/visualiza%C3%A7%C3%A3o-de-dados-com-seaborn-2fd0defd9adb

# %% [markdown]
# ## Desafio 6

# %%
sns.boxplot(y='g0', x='tratamento', data=dados)
plt.figure(figsize=(10,8))

# %%
sns.boxplot(y='g0', x='tempo', data=dados)
plt.figure(figsize=(10,8))

# %%
sns.boxplot(y='g0', x='dose', data=dados)
plt.figure(figsize=(10,8))

# %% [markdown]
# ## Desafio 7 - Resumo
# Na aula de hoje tive grande interesse, pois tive o primeiro contato com a criação e edição de gráficos, de uma forma mais interessante, digamos assim (para quem nunca havia trabalhado com Python).
# Além disto, tive o contato com ferramentas que são bem poderosas, com a obtenção de dados estatísticos utilizando o comando describe, ou a seleção de dados de forma mais "pro" utilizando o query e como a trabalhar com estes dados. Os desafios foram especialmente importantes, pois faz com que busquemos mais conteúdo através das bibliotecas, podendo gerar gráficos mais bem trabalhados e construídos.
